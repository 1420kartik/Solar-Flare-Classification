#####################################

MRSEQL_BIN_TSS = [0.000701538679397639, -2.737101409607226e-05, 0.0009362199347080349, 0.008902820427286962, 0.0024982610726247347, -0.00019159709867250582, 0.004236740612470739, 0.0010728427986516145, -4.4111808731197345e-05, 0.006927219613249779, 0.0021066593330534983, 0.0010118755533041774, -8.822361746239469e-05, 0.0007398743980645782, -0.00021896811276857808, -1.5241811336859273e-05, 0.003389830508474576, 0.0007270958251755985, -2.737101409607226e-05, 0.0]

MRSEQL_BIN_HSS2 = [0.0013731717556092185, -5.285466733822861e-05, 0.0018165851543759084, 0.017358439373949347, 0.004887304730679006, -0.000368369963939799, 0.008168406471961535, 0.0021076644166312664, -8.650655695875788e-05, 0.013478366657879015, 0.004092003366637623, 0.0019793100718239003, -0.0001725903300124565, 0.0014514709597193056, -0.00042068862313176327, -3.004113165211758e-05, 0.006642287488602171, 0.0014253320628365659, -5.285466733822861e-05, 0.0]

#####################################

LSTM_BIN_TSS = [0.02926529868646215, 0.023273592576346536, 0.11161004827815799, -0.0016461156243808015, 0, 0, 0.006741573033707865, -0.0006553978874849488, 0, 0, 0.046067415730337076, 0, 0, 0.02380504929645255, 0.02448394010570527, 0, 0, 0.0020023874550810787, 0, 0.03281717328687542]

LSTM_BIN_HSS2 = [0.05501630843215342, 0.04376092981447043, 0.19142966956307433, -0.002906314958970335, 0, 0, 0.01312296562527855, -0.0012353536940673023, 0, 0, 0.08643426292607603, 0, 0, 0.04494551995459355, 0.04555127727272383, 0, 0, 0.003855869033349156, 0, 0.05709489997386786]

# %% [markdown]
# # Averages

# %% [markdown]
# ### baseline

# %%
b1 = sum(SVM_BIN_TSS)/len(SVM_BIN_TSS)
b2 = sum(MR_BIN_TSS)/len(MR_BIN_TSS)
b3 = sum(LSTM_BIN_TSS)/len(LSTM_BIN_TSS)
b4 = sum(MRSEQL_BIN_TSS)/len(MRSEQL_BIN_TSS)
b5 = sum(CLF_BIN_TSS)/len(CLF_BIN_TSS)
b_all = (b1+b3+b4+b5)/4
print(b1, b2, b3, b4, b5)
(b2-b_all)*100
# Out:
# 0.07298480911936969 0.22133300833090944 0.014888248246863005 0.0016319047139649128 0.016342958872905322
# 19.48710280926337

# %%
b1 = sum(SVM_BIN_HSS2)/len(SVM_BIN_HSS2)
b2 = sum(MR_BIN_HSS2)/len(MR_BIN_HSS2)
b3 = sum(LSTM_BIN_HSS2)/len(LSTM_BIN_HSS2)
b4 = sum(MRSEQL_BIN_HSS2)/len(MRSEQL_BIN_HSS2)
b5 = sum(CLF_BIN_HSS2)/len(CLF_BIN_HSS2)
b_all = (b1+b3+b4+b5)/4
print(b1, b2, b3, b4, b5)
(b2-b_all)*100
# Out:
# 0.11247232592867559 0.28171157586250556 0.02685350169712748 0.003179821828516676 0.027146281907524987
# 23.929859302204438

# %% [markdown]
# ### Multi-class

# %%
b1 = sum(SVM_ALL_CLASS_HSS2)/len(SVM_ALL_CLASS_HSS2)
b2 = sum(MR_ALL_HSS2)/len(MR_ALL_HSS2)
print(b1, b2)
(b2-b1)*100
# Out:
# 0.12440877719694994 0.22806533892011713
# 10.365656172316719

# %%
b1 = sum(SVM_ALL_CLASS_TSS)/len(SVM_ALL_CLASS_TSS)
b2 = sum(MR_ALL_TSS)/len(MR_ALL_TSS)
print(b1, b2)
(b2-b1)*100
# Out:
# 0.08366969063408126 0.17986967171007323
# 9.619998107599196

# %%
svm1 = 0.07298480911936969
svm2 = 0.08366969063408126
(svm2-svm1)*100
# Out:
# 1.0684881514711573

# %%
svm1 = 0.11247232592867559
svm2 = 0.12440877719694994
(svm2-svm1)*100
# Out:
# 1.1936451268274348

# %%
mr1 = 0.22133300833090944
mr2 = 0.17986967171007323
(mr2-mr1)*100
# Out:
# -4.14633366208362

# %%
mr1 = 0.28171157586250556
mr2 = 0.22806533892011713
(mr2-mr1)*100
# Out:
# -5.364623694238843

# %% [markdown]
# ### Without BC binary

# %%
#TSS
b1 = sum(SVM_XBC_BIN_TSS)/len(SVM_XBC_BIN_TSS)
b2 = sum(MR_XBC_BIN_TSS)/len(MR_XBC_BIN_TSS)
print(b1, b2)
(b2-b1)*100
# Out:
# 0.31539407846239725 0.5220034853189084
# 20.660940685651113

# %%
#HSS2
b1 = sum(SVM_XBC_BIN_HSS2)/len(SVM_XBC_BIN_HSS2)
b2 = sum(MR_XBC_BIN_HSS2)/len(MR_XBC_BIN_HSS2)
print(b1, b2)
(b2-b1)*100
# Out:
# 0.3964768085258586 0.587294551988171
# 19.081774346231246

# %%
#TSS comaprison with baseline
svm1 = 0.07298480911936969
svm2 = 0.31539407846239725
(svm2-svm1)*100
# Out:
# 24.240926934302756

# %%
#TSS comaprison with baseline
mr1 = 0.22133300833090944
mr2 = 0.5220034853189084
(mr2-mr1)*100
# Out:
# 30.067047698799897

# %%
#HSS2 comaprison with baseline
svm1 = 0.11247232592867559
svm2 = 0.3964768085258586
(svm2-svm1)*100
# Out:
# 28.400448259718303

# %%
#HSS2 comaprison with baseline
mr1 = 0.28171157586250556
mr2 = 0.587294551988171
(mr2-mr1)*100
# Out:
# 30.558297612566548

# %% [markdown]
# ### Without BC all-class

# %%
#TSS
b1 = sum(SVM_XBC_ALL_TSS)/len(SVM_XBC_ALL_TSS)
b2 = sum(MR_XBC_ALL_TSS)/len(MR_XBC_ALL_TSS)
print(b1, b2)
(b2-b1)*100
# Out:
# 0.30831944483621926 0.5096607485658082
# 20.134130372958897

# %%
#HSS2
b1 = sum(SVM_XBC_ALL_HSS2)/len(SVM_XBC_ALL_HSS2)
b2 = sum(MR_XBC_ALL_HSS2)/len(MR_XBC_ALL_HSS2)
print(b1, b2)
(b2-b1)*100
# Out:
# 0.3908149817725817 0.5802879584257292
# 18.94729766531475

# %% [markdown]
# # VISUALIZATION

# %% [markdown]
# ### Baselines

# %%
plt.rcParams.update({'font.size': 20})
pair = np.arange(1,21)
plt.figure(figsize=(25,10))
plt.plot(pair, MR_BIN_TSS, label='MINIROCKET', marker='v')
plt.plot(pair, LSTM_BIN_TSS, label='LSTM', marker='s')
plt.plot(pair, SVM_BIN_TSS, label='SVM', marker='^')
plt.plot(pair, CLF_BIN_TSS, label='CLF', marker='o')
plt.plot(pair, MRSEQL_BIN_TSS, label='MRSEQL', marker='p')
plt.ylim([0, 0.7])
plt.xlabel("Train-Test partition pair", fontsize=20)
plt.ylabel("TSS", fontsize=20)
#plt.title("TSS Score Comparison", fontsize=20)
plt.legend()
plt.xticks(pair)
plt.grid(True)

# %% [markdown]
# TSS Baselines ^^^

# %%
pair = np.arange(1,21)
plt.figure(figsize=(25,10))
plt.plot(pair, MR_BIN_HSS2, label='MINIROCKET', marker='v')
plt.plot(pair, LSTM_BIN_HSS2, label='LSTM', marker='s')
plt.plot(pair, SVM_BIN_HSS2, label='SVM', marker='^')
plt.plot(pair, CLF_BIN_HSS2, label='CLF', marker='o')
plt.plot(pair, MRSEQL_BIN_HSS2, label='MRSEQL', marker='p')
plt.ylim([0, 0.7])
plt.xlabel("Train-Test partition pair", fontsize=20)
plt.ylabel("HSS2", fontsize=20)
#plt.title("HSS2 Score Comparison", fontsize=20)
plt.legend()
plt.xticks(pair)
plt.grid(True)

# %% [markdown]
# HSS2 Baselines ^^^

# %% [markdown]
# ### Without B and C class flares

# %%
pair = np.arange(1,21)
plt.figure(figsize=(25,10))
# plt.plot(pair, MR_BIN_TSS, label='TSS MiniRocket Bin', marker='v')
# plt.plot(pair, SVM_BIN_TSS, label='TSS SVM Bin', marker='s')
plt.plot(pair, MR_XBC_BIN_TSS, label='MINIROCKET', marker='v')
plt.plot(pair, SVM_XBC_BIN_TSS, label='SVM', marker='s')
plt.ylim([0, 0.7])
plt.xlabel("Train-Test partition pair")
plt.ylabel("TSS")
#plt.title("HSS2 Score Comparison")
plt.legend()
plt.xticks(pair)
plt.grid(True)

# %% [markdown]
# TSS Without B and C class flares / bin ^^^

# %%
pair = np.arange(1,21)
plt.figure(figsize=(25,10))
# plt.plot(pair, MR_BIN_TSS, label='TSS MiniRocket Bin', marker='v')
# plt.plot(pair, SVM_BIN_TSS, label='TSS SVM Bin', marker='s')
plt.plot(pair, MR_XBC_BIN_HSS2, label='MINIROCKET', marker='v')
plt.plot(pair, SVM_XBC_BIN_HSS2, label='SVM', marker='s')
plt.ylim([0, 0.7])
plt.xlabel("Train-Test partition pair")
plt.ylabel("HSS2")
#plt.title("HSS2 Score Comparison")
plt.legend(loc=1)
plt.xticks(pair)
plt.grid(True)

# %% [markdown]
# ###

# %% [markdown]
# HSS2 Without B and C class flares / bin ^^^

# %% [markdown]
# ### All Class classification

# %%
pair = np.arange(1,21)
plt.figure(figsize=(25,10))
# plt.plot(pair, MR_BIN_TSS, label='TSS MiniRocket Bin', marker='v')
# plt.plot(pair, SVM_BIN_TSS, label='TSS SVM Bin', marker='s')
plt.plot(pair, MR_ALL_TSS, label='MINIROCKET', marker='v')
plt.plot(pair, SVM_ALL_CLASS_TSS, label='SVM', marker='s')
plt.ylim([0, 0.7])
plt.xlabel("Train-Test partition pair")
plt.ylabel("TSS")
#plt.title("HSS2 Score Comparison")
plt.legend()
plt.xticks(pair)
plt.grid(True)

# %% [markdown]
# TSS All Class ^^^

# %%
pair = np.arange(1,21)
plt.figure(figsize=(25,10))
# plt.plot(pair, MR_BIN_TSS, label='TSS MiniRocket Bin', marker='v')
# plt.plot(pair, SVM_BIN_TSS, label='TSS SVM Bin', marker='s')
plt.plot(pair, MR_ALL_HSS2, label='MINIROCKET', marker='v')
plt.plot(pair, SVM_ALL_CLASS_HSS2, label='SVM', marker='s')
plt.ylim([0, 0.7])
plt.xlabel("Train-Test partition pair")
plt.ylabel("HSS2")
#plt.title("HSS2 Score Comparison")
plt.legend()
plt.xticks(pair)
plt.grid(True)

# %% [markdown]
# HSS2 All Class ^^^

# %% [markdown]
# ### Without BC - All Class

# %%
pair = np.arange(1,21)
plt.figure(figsize=(25,10))
# plt.plot(pair, MR_BIN_TSS, label='TSS MiniRocket Bin', marker='v')
# plt.plot(pair, SVM_BIN_TSS, label='TSS SVM Bin', marker='s')
plt.plot(pair, MR_XBC_ALL_TSS, label='MINIROCKET', marker='v')
plt.plot(pair, SVM_XBC_ALL_TSS, label='SVM', marker='s')
plt.ylim([0, 0.7])
plt.xlabel("Train-Test partition pair")
plt.ylabel("TSS")
#plt.title("HSS2 Score Comparison")
plt.legend()
plt.xticks(pair)
plt.grid(True)

# %%
pair = np.arange(1,21)
plt.figure(figsize=(25,10))
# plt.plot(pair, MR_BIN_TSS, label='TSS MiniRocket Bin', marker='v')
# plt.plot(pair, SVM_BIN_TSS, label='TSS SVM Bin', marker='s')
plt.plot(pair, MR_XBC_ALL_HSS2, label='MINIROCKET', marker='v')
plt.plot(pair, SVM_XBC_ALL_HSS2, label='SVM', marker='s')
plt.ylim([0, 0.7])
plt.xlabel("Train-Test partition pair")
plt.ylabel("HSS2")
#plt.title("HSS2 Score Comparison")
plt.legend(loc=1)
plt.xticks(pair)
plt.grid(True)

# %% [markdown]
# ### Azim Experiments

# %%
pair = np.arange(1,21)
plt.figure(figsize=(25,10))
plt.plot(pair, SVM_US_TSS, label='Undersampling', marker='v')
plt.plot(pair, SVM_BIN_TSS, label='None', marker='s')
plt.plot(pair, SVM_MW_TSS, label='Misclassification Weights', marker='s')
plt.plot(pair, SVM_OS_TSS, label='Oversampling', marker='p')
plt.ylim([0, 0.7])
plt.xlabel("Train-Test partition pair")
plt.ylabel("TSS")
#plt.title("HSS2 Score Comparison")
plt.legend(loc=1, title = "Remedies")
plt.xticks(pair)
plt.grid(True)

# %%
pair = np.arange(1,21)
plt.figure(figsize=(25,10))
plt.plot(pair, SVM_US_HSS2, label='Undersampling', marker='v')
plt.plot(pair, SVM_BIN_HSS2, label='None', marker='s')
plt.plot(pair, SVM_MW_HSS2, label='Misclassification Weights', marker='*')
plt.plot(pair, SVM_OS_HSS2, label='Oversampling', marker='p')
plt.ylim([0, 0.7])
plt.xlabel("Train-Test partition pair")
plt.ylabel("HSS2")
#plt.title("HSS2 Score Comparison")
plt.legend(title = "Remedies")
plt.xticks(pair)
plt.grid(True)

# %%
z = 5
0 <= z < 10
# Out:
# True

# %%
True and False
# Out:
# False

# %%
not True
# Out:
# False

# %%
a = float('inf')

# %%
a
# Out:
# inf
